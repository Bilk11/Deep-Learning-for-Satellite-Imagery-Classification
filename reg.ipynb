# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1: Adam Foldvari
# - Alumno 2: Mate Lukacs
# - Alumno 3: Joseph Tartivel
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/4oNHlRFEd71HXp4](https://drive.upm.es/s/4oNHlRFEd71HXp4)

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Helicopter', 2: 'Small car', 3: 'Bus', 4: 'Truck', 5: 'Motorboat', 6: 'Fishing vessel', 7: 'Dump truck', 8: 'Excavator', 9: 'Building', 10: 'Storage tank', 11: 'Shipping container'}

# %%
import warnings
import rasterio
import numpy as np

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    src_raster = rasterio.open('/kaggle/input/files/xview_recognition/'+filename, 'r')
    # RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    return img

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json

# Load database
json_file = '/kaggle/input/files/xview_recognition/xview_ann_train.json'
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Helicopter': 70, 'Small car': 4290, 'Bus': 2155, 'Truck': 2746, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 4689, 'Storage tank': 1469, 'Shipping container': 1523}

# %%
from sklearn.model_selection import train_test_split

anns_train, anns_valid = train_test_split(anns, test_size=0.1, random_state=1, shuffle=True)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 19239
# Number of validation images: 2138

# %%
# Load architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, LeakyReLU #ADDED

print('Load model')
model = Sequential()
model.add(Flatten(input_shape=(224, 224, 3)))

# Hidden layers with batch normalization ADDED
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.4))

model.add(Dense(128))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.3))

# Output layer
model.add(Dense(len(categories), activation='softmax'))
#UNTIL this


model.summary()
# Out:
# Load model
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 150528)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │      77,070,848 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 12)                  │           1,548 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 77,240,204 (294.65 MB)
#  Trainable params: 77,238,412 (294.64 MB)
#  Non-trainable params: 1,792 (7.00 KB)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler #ADDED

# Learning rate is changed to 0.001
opt = Adam(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-7, amsgrad=True, clipnorm=1.0)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True)
lr_callback = ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=3,verbose=1,mode='min',min_lr=1e-6) # Add adaptive learning rate
early_stop = EarlyStopping('val_accuracy', patience=40, verbose=1)
terminate = TerminateOnNaN()
callbacks = [model_checkpoint, lr_callback, early_stop, terminate]

# %%
def generator_images(objs, batch_size, do_shuffle=False):
    while True:
        if do_shuffle:
            np.random.shuffle(objs)
        groups = [objs[i:i+batch_size] for i in range(0, len(objs), batch_size)]
        for group in groups:
            images, labels = [], []
            for (filename, obj) in group:
                # Load image
                images.append(load_geoimage(filename))
                probabilities = np.zeros(len(categories))
                probabilities[list(categories.values()).index(obj.category)] = 1
                labels.append(probabilities)
            images = np.array(images).astype(np.float32)
            labels = np.array(labels).astype(np.float32)
            yield images, labels

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]
# Generators
batch_size = 32
train_generator = generator_images(objs_train, batch_size, do_shuffle=True)
valid_generator = generator_images(objs_valid, batch_size, do_shuffle=False)

# %%
import math
import numpy as np

print('Training model')
epochs = 60
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)
h = model.fit(train_generator, steps_per_epoch=train_steps, validation_data=valid_generator, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks, verbose=1)
# Best validation model
best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model
# Epoch 1/60
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 0s 988ms/step - accuracy: 0.2875 - loss: 2.1477
# Epoch 1: val_accuracy improved from -inf to 0.44107, saving model to model.keras
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 675s 1s/step - accuracy: 0.2876 - loss: 2.1473 - val_accuracy: 0.4411 - val_loss: 1.5893 - learning_rate: 0.0010
# Epoch 2/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.4260 - loss: 1.6517
# Epoch 2: val_accuracy improved from 0.44107 to 0.49579, saving model to model.keras
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 98s 162ms/step - accuracy: 0.4260 - loss: 1.6517 - val_accuracy: 0.4958 - val_loss: 1.4635 - learning_rate: 0.0010
# Epoch 3/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.4545 - loss: 1.5637
# Epoch 3: val_accuracy improved from 0.49579 to 0.52058, saving model to model.keras
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 86s 143ms/step - accuracy: 0.4545 - loss: 1.5636 - val_accuracy: 0.5206 - val_loss: 1.4191 - learning_rate: 0.0010
# Epoch 4/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.4691 - loss: 1.5144
# Epoch 4: val_accuracy did not improve from 0.52058
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 78s 129ms/step - accuracy: 0.4691 - loss: 1.5144 - val_accuracy: 0.5122 - val_loss: 1.3838 - learning_rate: 0.0010
# Epoch 5/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.4911 - loss: 1.4713
# Epoch 5: val_accuracy improved from 0.52058 to 0.54537, saving model to model.keras
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 83s 137ms/step - accuracy: 0.4911 - loss: 1.4713 - val_accuracy: 0.5454 - val_loss: 1.3439 - learning_rate: 0.0010
# Epoch 6/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4981 - loss: 1.4505
# Epoch 6: val_accuracy did not improve from 0.54537
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 74s 123ms/step - accuracy: 0.4981 - loss: 1.4505 - val_accuracy: 0.5164 - val_loss: 1.4066 - learning_rate: 0.0010
# Epoch 7/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.5157 - loss: 1.4094
# Epoch 7: val_accuracy did not improve from 0.54537
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 72s 119ms/step - accuracy: 0.5157 - loss: 1.4094 - val_accuracy: 0.5136 - val_loss: 1.4231 - learning_rate: 0.0010
# Epoch 8/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.5193 - loss: 1.3979
# Epoch 8: val_accuracy improved from 0.54537 to 0.55192, saving model to model.keras
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 84s 139ms/step - accuracy: 0.5193 - loss: 1.3979 - val_accuracy: 0.5519 - val_loss: 1.3039 - learning_rate: 0.0010
# Epoch 9/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.5282 - loss: 1.3710
# Epoch 9: val_accuracy did not improve from 0.55192
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 77s 129ms/step - accuracy: 0.5282 - loss: 1.3710 - val_accuracy: 0.5505 - val_loss: 1.3065 - learning_rate: 0.0010
# Epoch 10/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.5365 - loss: 1.3460
# Epoch 10: val_accuracy did not improve from 0.55192
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 79s 131ms/step - accuracy: 0.5364 - loss: 1.3461 - val_accuracy: 0.5449 - val_loss: 1.3192 - learning_rate: 0.0010
# Epoch 11/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.5294 - loss: 1.3530
# Epoch 11: val_accuracy did not improve from 0.55192
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 79s 131ms/step - accuracy: 0.5294 - loss: 1.3530 - val_accuracy: 0.5407 - val_loss: 1.3155 - learning_rate: 0.0010
# Epoch 12/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.5524 - loss: 1.2871
# Epoch 12: val_accuracy improved from 0.55192 to 0.59027, saving model to model.keras
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 86s 143ms/step - accuracy: 0.5524 - loss: 1.2872 - val_accuracy: 0.5903 - val_loss: 1.1938 - learning_rate: 5.0000e-04
# Epoch 13/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.5535 - loss: 1.2717
# Epoch 13: val_accuracy improved from 0.59027 to 0.59074, saving model to model.keras
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 77s 129ms/step - accuracy: 0.5535 - loss: 1.2718 - val_accuracy: 0.5907 - val_loss: 1.2021 - learning_rate: 5.0000e-04
# Epoch 14/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.5565 - loss: 1.2678
# Epoch 14: val_accuracy improved from 0.59074 to 0.60103, saving model to model.keras
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 78s 130ms/step - accuracy: 0.5565 - loss: 1.2679 - val_accuracy: 0.6010 - val_loss: 1.1810 - learning_rate: 5.0000e-04
# Epoch 15/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5611 - loss: 1.2669
# Epoch 15: val_accuracy did not improve from 0.60103
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 71s 117ms/step - accuracy: 0.5612 - loss: 1.2669 - val_accuracy: 0.5636 - val_loss: 1.2541 - learning_rate: 5.0000e-04
# Epoch 16/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.5650 - loss: 1.2583
# Epoch 16: val_accuracy did not improve from 0.60103
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 76s 126ms/step - accuracy: 0.5650 - loss: 1.2582 - val_accuracy: 0.5959 - val_loss: 1.1679 - learning_rate: 5.0000e-04
# Epoch 17/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.5634 - loss: 1.2597
# Epoch 17: val_accuracy did not improve from 0.60103
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 76s 126ms/step - accuracy: 0.5634 - loss: 1.2597 - val_accuracy: 0.5987 - val_loss: 1.1611 - learning_rate: 5.0000e-04
# Epoch 18/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.5666 - loss: 1.2395
# Epoch 18: val_accuracy did not improve from 0.60103
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 79s 131ms/step - accuracy: 0.5666 - loss: 1.2395 - val_accuracy: 0.5931 - val_loss: 1.1703 - learning_rate: 5.0000e-04
# Epoch 19/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.5755 - loss: 1.2230
# Epoch 19: val_accuracy did not improve from 0.60103
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 78s 130ms/step - accuracy: 0.5755 - loss: 1.2230 - val_accuracy: 0.5870 - val_loss: 1.1817 - learning_rate: 5.0000e-04
# Epoch 20/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.5772 - loss: 1.2232
# Epoch 20: val_accuracy did not improve from 0.60103
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 78s 130ms/step - accuracy: 0.5772 - loss: 1.2232 - val_accuracy: 0.5935 - val_loss: 1.1714 - learning_rate: 5.0000e-04
# Epoch 21/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.5884 - loss: 1.1958
# Epoch 21: val_accuracy did not improve from 0.60103
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 78s 129ms/step - accuracy: 0.5884 - loss: 1.1958 - val_accuracy: 0.5968 - val_loss: 1.1442 - learning_rate: 2.5000e-04
# Epoch 22/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.5938 - loss: 1.1710
# Epoch 22: val_accuracy improved from 0.60103 to 0.61880, saving model to model.keras
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 82s 137ms/step - accuracy: 0.5938 - loss: 1.1710 - val_accuracy: 0.6188 - val_loss: 1.1186 - learning_rate: 2.5000e-04
# Epoch 23/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5970 - loss: 1.1655
# Epoch 23: val_accuracy did not improve from 0.61880
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 71s 118ms/step - accuracy: 0.5970 - loss: 1.1655 - val_accuracy: 0.6155 - val_loss: 1.1189 - learning_rate: 2.5000e-04
# Epoch 24/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.6049 - loss: 1.1362
# Epoch 24: val_accuracy did not improve from 0.61880
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 75s 124ms/step - accuracy: 0.6049 - loss: 1.1362 - val_accuracy: 0.6024 - val_loss: 1.1356 - learning_rate: 2.5000e-04
# Epoch 25/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6007 - loss: 1.1486
# Epoch 25: val_accuracy did not improve from 0.61880
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 75s 124ms/step - accuracy: 0.6007 - loss: 1.1487 - val_accuracy: 0.6174 - val_loss: 1.1111 - learning_rate: 2.5000e-04
# Epoch 26/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.6058 - loss: 1.1320
# Epoch 26: val_accuracy did not improve from 0.61880
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 77s 127ms/step - accuracy: 0.6057 - loss: 1.1321 - val_accuracy: 0.6183 - val_loss: 1.1219 - learning_rate: 2.5000e-04
# Epoch 27/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.5984 - loss: 1.1452
# Epoch 27: val_accuracy did not improve from 0.61880
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 77s 128ms/step - accuracy: 0.5984 - loss: 1.1452 - val_accuracy: 0.6080 - val_loss: 1.1349 - learning_rate: 2.5000e-04
# Epoch 28/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.6111 - loss: 1.1230
# Epoch 28: val_accuracy did not improve from 0.61880
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 78s 130ms/step - accuracy: 0.6111 - loss: 1.1230 - val_accuracy: 0.6104 - val_loss: 1.1314 - learning_rate: 2.5000e-04
# Epoch 29/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.6098 - loss: 1.1303
# Epoch 29: val_accuracy improved from 0.61880 to 0.62488, saving model to model.keras
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 81s 135ms/step - accuracy: 0.6098 - loss: 1.1302 - val_accuracy: 0.6249 - val_loss: 1.0927 - learning_rate: 1.2500e-04
# Epoch 30/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.6153 - loss: 1.1144
# Epoch 30: val_accuracy improved from 0.62488 to 0.63003, saving model to model.keras
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 80s 132ms/step - accuracy: 0.6153 - loss: 1.1144 - val_accuracy: 0.6300 - val_loss: 1.0834 - learning_rate: 1.2500e-04
# Epoch 31/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.6145 - loss: 1.1164
# Epoch 31: val_accuracy improved from 0.63003 to 0.63471, saving model to model.keras
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 78s 129ms/step - accuracy: 0.6145 - loss: 1.1164 - val_accuracy: 0.6347 - val_loss: 1.0800 - learning_rate: 1.2500e-04
# Epoch 32/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.6101 - loss: 1.1083
# Epoch 32: val_accuracy did not improve from 0.63471
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 70s 117ms/step - accuracy: 0.6101 - loss: 1.1083 - val_accuracy: 0.6305 - val_loss: 1.0951 - learning_rate: 1.2500e-04
# Epoch 33/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6166 - loss: 1.1032
# Epoch 33: val_accuracy did not improve from 0.63471
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 76s 126ms/step - accuracy: 0.6166 - loss: 1.1032 - val_accuracy: 0.6342 - val_loss: 1.0828 - learning_rate: 1.2500e-04
# Epoch 34/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.6163 - loss: 1.0992
# Epoch 34: val_accuracy improved from 0.63471 to 0.64172, saving model to model.keras
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 83s 138ms/step - accuracy: 0.6163 - loss: 1.0993 - val_accuracy: 0.6417 - val_loss: 1.0790 - learning_rate: 1.2500e-04
# Epoch 35/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.6122 - loss: 1.1093
# Epoch 35: val_accuracy did not improve from 0.64172
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 71s 118ms/step - accuracy: 0.6122 - loss: 1.1092 - val_accuracy: 0.6300 - val_loss: 1.0869 - learning_rate: 1.2500e-04
# Epoch 36/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.6213 - loss: 1.0842
# Epoch 36: val_accuracy did not improve from 0.64172
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 74s 124ms/step - accuracy: 0.6212 - loss: 1.0843 - val_accuracy: 0.6347 - val_loss: 1.0829 - learning_rate: 1.2500e-04
# Epoch 37/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6229 - loss: 1.0871
# Epoch 37: val_accuracy did not improve from 0.64172
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 74s 123ms/step - accuracy: 0.6229 - loss: 1.0871 - val_accuracy: 0.6333 - val_loss: 1.0868 - learning_rate: 1.2500e-04
# Epoch 38/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.6277 - loss: 1.0720
# Epoch 38: val_accuracy improved from 0.64172 to 0.64359, saving model to model.keras
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 80s 133ms/step - accuracy: 0.6277 - loss: 1.0720 - val_accuracy: 0.6436 - val_loss: 1.0616 - learning_rate: 6.2500e-05
# Epoch 39/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.6281 - loss: 1.0713
# Epoch 39: val_accuracy did not improve from 0.64359
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 69s 115ms/step - accuracy: 0.6281 - loss: 1.0713 - val_accuracy: 0.6403 - val_loss: 1.0630 - learning_rate: 6.2500e-05
# Epoch 40/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.6383 - loss: 1.0500
# Epoch 40: val_accuracy did not improve from 0.64359
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 73s 122ms/step - accuracy: 0.6383 - loss: 1.0501 - val_accuracy: 0.6403 - val_loss: 1.0667 - learning_rate: 6.2500e-05
# Epoch 41/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.6267 - loss: 1.0721
# Epoch 41: val_accuracy did not improve from 0.64359
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 73s 121ms/step - accuracy: 0.6267 - loss: 1.0721 - val_accuracy: 0.6403 - val_loss: 1.0626 - learning_rate: 6.2500e-05
# Epoch 42/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6258 - loss: 1.0760
# Epoch 42: val_accuracy improved from 0.64359 to 0.64593, saving model to model.keras
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 82s 136ms/step - accuracy: 0.6258 - loss: 1.0760 - val_accuracy: 0.6459 - val_loss: 1.0587 - learning_rate: 3.1250e-05
# Epoch 43/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.6336 - loss: 1.0627
# Epoch 43: val_accuracy did not improve from 0.64593
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 69s 114ms/step - accuracy: 0.6336 - loss: 1.0627 - val_accuracy: 0.6450 - val_loss: 1.0587 - learning_rate: 3.1250e-05
# Epoch 44/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6324 - loss: 1.0574
# Epoch 44: val_accuracy improved from 0.64593 to 0.64920, saving model to model.keras
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 81s 134ms/step - accuracy: 0.6324 - loss: 1.0575 - val_accuracy: 0.6492 - val_loss: 1.0590 - learning_rate: 3.1250e-05
# Epoch 45/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.6315 - loss: 1.0521
# Epoch 45: val_accuracy did not improve from 0.64920
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 68s 114ms/step - accuracy: 0.6315 - loss: 1.0521 - val_accuracy: 0.6436 - val_loss: 1.0548 - learning_rate: 3.1250e-05
# Epoch 46/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6277 - loss: 1.0693
# Epoch 46: val_accuracy did not improve from 0.64920
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 74s 123ms/step - accuracy: 0.6278 - loss: 1.0693 - val_accuracy: 0.6431 - val_loss: 1.0559 - learning_rate: 3.1250e-05
# Epoch 47/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6262 - loss: 1.0657
# Epoch 47: val_accuracy did not improve from 0.64920
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 75s 124ms/step - accuracy: 0.6263 - loss: 1.0656 - val_accuracy: 0.6450 - val_loss: 1.0565 - learning_rate: 3.1250e-05
# Epoch 48/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.6322 - loss: 1.0606
# Epoch 48: val_accuracy did not improve from 0.64920
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 72s 120ms/step - accuracy: 0.6322 - loss: 1.0605 - val_accuracy: 0.6483 - val_loss: 1.0581 - learning_rate: 3.1250e-05
# Epoch 49/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.6351 - loss: 1.0489
# Epoch 49: val_accuracy did not improve from 0.64920
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 75s 124ms/step - accuracy: 0.6351 - loss: 1.0489 - val_accuracy: 0.6469 - val_loss: 1.0564 - learning_rate: 1.5625e-05
# Epoch 50/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.6276 - loss: 1.0707
# Epoch 50: val_accuracy did not improve from 0.64920
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 76s 127ms/step - accuracy: 0.6276 - loss: 1.0707 - val_accuracy: 0.6487 - val_loss: 1.0586 - learning_rate: 1.5625e-05
# Epoch 51/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6362 - loss: 1.0569
# Epoch 51: val_accuracy improved from 0.64920 to 0.65014, saving model to model.keras
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 81s 135ms/step - accuracy: 0.6362 - loss: 1.0569 - val_accuracy: 0.6501 - val_loss: 1.0564 - learning_rate: 1.5625e-05
# Epoch 52/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.6292 - loss: 1.0544
# Epoch 52: val_accuracy did not improve from 0.65014
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 67s 112ms/step - accuracy: 0.6292 - loss: 1.0544 - val_accuracy: 0.6469 - val_loss: 1.0537 - learning_rate: 7.8125e-06
# Epoch 53/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.6330 - loss: 1.0423
# Epoch 53: val_accuracy did not improve from 0.65014
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 73s 121ms/step - accuracy: 0.6330 - loss: 1.0424 - val_accuracy: 0.6469 - val_loss: 1.0534 - learning_rate: 7.8125e-06
# Epoch 54/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.6322 - loss: 1.0524
# Epoch 54: val_accuracy did not improve from 0.65014
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 73s 122ms/step - accuracy: 0.6322 - loss: 1.0524 - val_accuracy: 0.6469 - val_loss: 1.0531 - learning_rate: 7.8125e-06
# Epoch 55/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.6311 - loss: 1.0560
# Epoch 55: val_accuracy did not improve from 0.65014
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 75s 124ms/step - accuracy: 0.6311 - loss: 1.0560 - val_accuracy: 0.6473 - val_loss: 1.0546 - learning_rate: 7.8125e-06
# Epoch 56/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.6355 - loss: 1.0443
# Epoch 56: val_accuracy did not improve from 0.65014
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 73s 122ms/step - accuracy: 0.6355 - loss: 1.0443 - val_accuracy: 0.6487 - val_loss: 1.0532 - learning_rate: 7.8125e-06
# Epoch 57/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6379 - loss: 1.0513
# Epoch 57: val_accuracy did not improve from 0.65014
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 74s 122ms/step - accuracy: 0.6379 - loss: 1.0513 - val_accuracy: 0.6492 - val_loss: 1.0532 - learning_rate: 7.8125e-06
# Epoch 58/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.6334 - loss: 1.0528
# Epoch 58: val_accuracy did not improve from 0.65014
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 73s 122ms/step - accuracy: 0.6334 - loss: 1.0528 - val_accuracy: 0.6483 - val_loss: 1.0550 - learning_rate: 3.9063e-06
# Epoch 59/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6324 - loss: 1.0419
# Epoch 59: val_accuracy improved from 0.65014 to 0.65201, saving model to model.keras
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 80s 134ms/step - accuracy: 0.6324 - loss: 1.0420 - val_accuracy: 0.6520 - val_loss: 1.0540 - learning_rate: 3.9063e-06
# Epoch 60/60
# 601/602 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.6321 - loss: 1.0493
# Epoch 60: val_accuracy did not improve from 0.65201
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 602/602 ━━━━━━━━━━━━━━━━━━━━ 71s 118ms/step - accuracy: 0.6322 - loss: 1.0493 - val_accuracy: 0.6520 - val_loss: 1.0538 - learning_rate: 3.9063e-06
# Best validation model: epoch 59  - val_accuracy 0.6520112156867981

# %%
#PLOTS

import matplotlib.pyplot as plt

# Create subplots with custom styling
plt.figure(figsize=(12, 5), dpi=300)
plt.style.use('seaborn-whitegrid')

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(h.history['loss'], color='#1f77b4', linewidth=2, label='Train')
plt.plot(h.history['val_loss'], color='#ff7f0e', linewidth=2, linestyle='--', label='Validation')
plt.title('Training Evolution: Loss', fontsize=12, pad=20)
plt.ylabel('Categorical Crossentropy', fontsize=10)
plt.xlabel('Epoch', fontsize=10)
plt.legend(frameon=True, facecolor='white')

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(h.history['accuracy'], color='#1f77b4', linewidth=2, label='Train')
plt.plot(h.history['val_accuracy'], color='#ff7f0e', linewidth=2, linestyle='--', label='Validation')
plt.title('Training Evolution: Accuracy', fontsize=12, pad=20)
plt.ylabel('Accuracy (%)', fontsize=10)
plt.xlabel('Epoch', fontsize=10)
plt.legend(frameon=True, facecolor='white')

plt.tight_layout()
plt.savefig('training_evolution.png', bbox_inches='tight', transparent=False)
plt.show()
# Out:
# <ipython-input-15-b3401fe3e391>:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.get_cmap('Blues'))
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show(fig)

# %%
import numpy as np

model.load_weights('model.keras') #, by_name=True
y_true, y_pred = [], []
for ann in anns_valid:
    # Load image
    image = load_geoimage(ann.filename)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        y_true.append(obj_pred.category)
        y_pred.append(pred_category)

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)
# Out:
# <ipython-input-16-39df9ea0fe34>:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.get_cmap('Blues'))

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 65.201%
# Mean Recall: 55.707%
# Mean Precision: 57.611%
# > Cargo plane: Recall: 73.529% Precision: 86.207% Specificity: 99.614% Dice: 79.365%
# > Helicopter: Recall: 0.000% Precision: 0.000% Specificity: 99.953% Dice: 0.000%
# > Small car: Recall: 90.476% Precision: 71.563% Specificity: 91.211% Dice: 79.916%
# > Bus: Recall: 49.772% Precision: 56.477% Specificity: 95.623% Dice: 52.913%
# > Truck: Recall: 20.377% Precision: 36.000% Specificity: 94.875% Dice: 26.024%
# > Motorboat: Recall: 52.809% Precision: 60.256% Specificity: 98.487% Dice: 56.287%
# > Fishing vessel: Recall: 61.039% Precision: 64.384% Specificity: 98.738% Dice: 62.667%
# > Dump truck: Recall: 52.991% Precision: 59.615% Specificity: 97.922% Dice: 56.109%
# > Excavator: Recall: 69.231% Precision: 51.429% Specificity: 97.524% Dice: 59.016%
# > Building: Recall: 83.669% Precision: 74.373% Specificity: 91.291% Dice: 78.748%
# > Storage tank: Recall: 47.712% Precision: 77.660% Specificity: 98.942% Dice: 59.109%
# > Shipping container: Recall: 66.883% Precision: 53.368% Specificity: 95.464% Dice: 59.366%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
for (dirpath, dirnames, filenames) in os.walk('/kaggle/input/files/xview_recognition/xview_test'):
    for filename in filenames:
        image = GenericImage(dirpath[18:]+'/'+filename)
        image.tile = np.array([0, 0, 224, 224])
        obj = GenericObject()
        obj.bb = (0, 0, 224, 224)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2635

# %%
import numpy as np

model.load_weights('model.keras') #, by_name=True
predictions_data = {"images": {}, "annotations": {}}
for idx, ann in enumerate(anns):
    file_name = ann.filename.split('/')[-1]
    image_data = {"image_id": file_name, "filename": file_name, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
    predictions_data["images"][idx] = image_data
    # Load image
    image = load_geoimage('xview_test/' + file_name)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
        predictions_data["annotations"][idx] = annotation_data

# %%
with open("/kaggle/working/prediction_second.json", "w") as outfile:
    json.dump(predictions_data, outfile)

# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1: Adam Foldvari
# - Alumno 2: Mate Lukacs
# - Alumno 3: Joseph Tartivel
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/4oNHlRFEd71HXp4](https://drive.upm.es/s/4oNHlRFEd71HXp4)

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Helicopter', 2: 'Small car', 3: 'Bus', 4: 'Truck', 5: 'Motorboat', 6: 'Fishing vessel', 7: 'Dump truck', 8: 'Excavator', 9: 'Building', 10: 'Storage tank', 11: 'Shipping container'}

# %%
import warnings
import rasterio
import numpy as np

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    src_raster = rasterio.open('/kaggle/input/files/xview_recognition/'+filename, 'r')
    # RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    img = img / 255.0  # Normalize pixel values to [0,1]
    return img

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json

# Load database
json_file = '/kaggle/input/files/xview_recognition/xview_ann_train.json'
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Helicopter': 70, 'Small car': 4290, 'Bus': 2155, 'Truck': 2746, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 4689, 'Storage tank': 1469, 'Shipping container': 1523}

# %%
from sklearn.model_selection import train_test_split

anns_train, anns_valid = train_test_split(anns, test_size=0.1, random_state=1, shuffle=True)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 19239
# Number of validation images: 2138

# %%
# Load architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, RandomFlip, RandomRotation, Conv2D, MaxPooling2D, Dense, Dropout, Activation, Flatten, BatchNormalization, RandomZoom, RandomContrast, RandomBrightness, RandomCrop, GaussianNoise
from tensorflow.keras.regularizers import l2


print('Load model')
model = Sequential()

# 1. Input Layer (explicitly define input tensor)
model.add(Input(shape=(224, 224, 3)))

# 2. Data Augmentation Layers
model.add(RandomFlip("horizontal_and_vertical"))
model.add(RandomRotation(0.2))  # 20% rotation
model.add(RandomZoom(0.2))        # Randomly zoom images by up to 20%
model.add(RandomContrast(0.2))   # Adjust image contrast randomly

# 3. Existing CNN Architecture
model.add(Conv2D(32, (3,3), activation='relu', padding='same', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, (3,3), activation='relu', padding='same', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(128, (3,3), activation='relu', padding='same', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

# Add 3 more Conv-Pool block
model.add(Conv2D(256, (3,3), activation='relu', padding='same', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(512, (3,3), activation='relu', padding='same', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(1024, (3,3), activation='relu', padding='same', kernel_regularizer=l2(1e-4)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

# Flatten before dense layers
model.add(Flatten())

# Existing dense layers with batch normalization
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.6))

model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(128))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.4))

# Output layer
model.add(Dense(len(categories), activation='softmax'))

model.summary()
# Out:
# Load model
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_rotation (RandomRotation)     │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_zoom (RandomZoom)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_contrast (RandomContrast)     │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 224, 224, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 224, 224, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 112, 112, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 112, 112, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 112, 112, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 56, 56, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 56, 56, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 56, 56, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 28, 28, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 28, 28, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 28, 28, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 14, 14, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 14, 14, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 14, 14, 512)         │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 7, 7, 1024)          │       4,719,616 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 7, 7, 1024)          │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 3, 3, 1024)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 9216)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       4,719,104 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 12)                  │           1,548 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 11,184,716 (42.67 MB)
#  Trainable params: 11,178,892 (42.64 MB)
#  Non-trainable params: 5,824 (22.75 KB)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler

def custom_lr_schedule(epoch):
    base_lr = 1e-3
    warmup_epochs = 5
    
    if epoch < warmup_epochs:
        return base_lr * (epoch + 1) / warmup_epochs
    
    if epoch % 20 == 0 and epoch != 0:
        return base_lr * 0.5
    
    return base_lr * (0.95 ** epoch)

opt = Adam(
   learning_rate=custom_lr_schedule(0),
   beta_1=0.9,
   epsilon=1e-7,
   clipnorm=1.0)

model.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
lr_callback = LearningRateScheduler(custom_lr_schedule, verbose=1)
early_stop = EarlyStopping(monitor='val_accuracy', patience=20, verbose=1, restore_best_weights=True, mode='max')
terminate = TerminateOnNaN()
callbacks = [model_checkpoint, lr_callback, early_stop, terminate]

# %%
def generator_images(objs, batch_size, do_shuffle=False):
    while True:
        if do_shuffle:
            np.random.shuffle(objs)
        groups = [objs[i:i+batch_size] for i in range(0, len(objs), batch_size)]
        for group in groups:
            images, labels = [], []
            for (filename, obj) in group:
                # Load image
                images.append(load_geoimage(filename))
                probabilities = np.zeros(len(categories))
                probabilities[list(categories.values()).index(obj.category)] = 1
                labels.append(probabilities)
            images = np.array(images).astype(np.float32)
            labels = np.array(labels).astype(np.float32)
            # Force channels-last format
            images = np.transpose(images, (0, 1, 2, 3))  # Swap width/channel axes
            yield images, labels

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]
# Generators
batch_size = 64
train_generator = generator_images(objs_train, batch_size, do_shuffle=True)
valid_generator = generator_images(objs_valid, batch_size, do_shuffle=False)

# %%
import math
import numpy as np

print('Training model')
epochs = 80
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)

# Pass class_weights to model.fit()
h = model.fit(train_generator, steps_per_epoch=train_steps,
              validation_data=valid_generator, validation_steps=valid_steps,
              epochs=epochs, callbacks=callbacks, verbose=1)

best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.0002.
# Epoch 1/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2216 - loss: 2.5403
# Epoch 1: val_accuracy improved from -inf to 0.13985, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 798s 3s/step - accuracy: 0.2219 - loss: 2.5395 - val_accuracy: 0.1399 - val_loss: 2.7698 - learning_rate: 2.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0004.
# Epoch 2/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.4031 - loss: 1.9352
# Epoch 2: val_accuracy improved from 0.13985 to 0.49906, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 110s 365ms/step - accuracy: 0.4032 - loss: 1.9350 - val_accuracy: 0.4991 - val_loss: 1.5864 - learning_rate: 4.0000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0006000000000000001.
# Epoch 3/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.4546 - loss: 1.7196
# Epoch 3: val_accuracy did not improve from 0.49906
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 103s 342ms/step - accuracy: 0.4546 - loss: 1.7194 - val_accuracy: 0.4878 - val_loss: 1.5949 - learning_rate: 6.0000e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0008.
# Epoch 4/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.5074 - loss: 1.5732
# Epoch 4: val_accuracy improved from 0.49906 to 0.55239, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 104s 345ms/step - accuracy: 0.5075 - loss: 1.5731 - val_accuracy: 0.5524 - val_loss: 1.4767 - learning_rate: 8.0000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.001.
# Epoch 5/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.5419 - loss: 1.4777
# Epoch 5: val_accuracy did not improve from 0.55239
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 99s 328ms/step - accuracy: 0.5419 - loss: 1.4777 - val_accuracy: 0.3653 - val_loss: 2.2167 - learning_rate: 0.0010
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0007737809374999998.
# Epoch 6/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.5696 - loss: 1.4029
# Epoch 6: val_accuracy improved from 0.55239 to 0.57016, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 96s 319ms/step - accuracy: 0.5696 - loss: 1.4028 - val_accuracy: 0.5702 - val_loss: 1.4213 - learning_rate: 7.7378e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.0007350918906249999.
# Epoch 7/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.5898 - loss: 1.3584
# Epoch 7: val_accuracy improved from 0.57016 to 0.61553, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 97s 324ms/step - accuracy: 0.5899 - loss: 1.3583 - val_accuracy: 0.6155 - val_loss: 1.2934 - learning_rate: 7.3509e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0006983372960937497.
# Epoch 8/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.6116 - loss: 1.3136
# Epoch 8: val_accuracy improved from 0.61553 to 0.62114, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 99s 329ms/step - accuracy: 0.6116 - loss: 1.3135 - val_accuracy: 0.6211 - val_loss: 1.2885 - learning_rate: 6.9834e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0006634204312890623.
# Epoch 9/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.6274 - loss: 1.2767
# Epoch 9: val_accuracy did not improve from 0.62114
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 97s 323ms/step - accuracy: 0.6274 - loss: 1.2767 - val_accuracy: 0.6010 - val_loss: 1.3416 - learning_rate: 6.6342e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.0006302494097246091.
# Epoch 10/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.6374 - loss: 1.2816
# Epoch 10: val_accuracy improved from 0.62114 to 0.65108, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 103s 343ms/step - accuracy: 0.6374 - loss: 1.2816 - val_accuracy: 0.6511 - val_loss: 1.2522 - learning_rate: 6.3025e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0005987369392383787.
# Epoch 11/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.6450 - loss: 1.2451
# Epoch 11: val_accuracy improved from 0.65108 to 0.66604, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 103s 342ms/step - accuracy: 0.6450 - loss: 1.2451 - val_accuracy: 0.6660 - val_loss: 1.1888 - learning_rate: 5.9874e-04
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0005688000922764596.
# Epoch 12/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.6470 - loss: 1.2310
# Epoch 12: val_accuracy improved from 0.66604 to 0.67493, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 103s 344ms/step - accuracy: 0.6471 - loss: 1.2311 - val_accuracy: 0.6749 - val_loss: 1.1671 - learning_rate: 5.6880e-04
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0005403600876626366.
# Epoch 13/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.6578 - loss: 1.2259
# Epoch 13: val_accuracy did not improve from 0.67493
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 101s 336ms/step - accuracy: 0.6578 - loss: 1.2259 - val_accuracy: 0.6431 - val_loss: 1.2370 - learning_rate: 5.4036e-04
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0005133420832795048.
# Epoch 14/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.6686 - loss: 1.1950
# Epoch 14: val_accuracy did not improve from 0.67493
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 339ms/step - accuracy: 0.6686 - loss: 1.1950 - val_accuracy: 0.6310 - val_loss: 1.2765 - learning_rate: 5.1334e-04
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.00048767497911552955.
# Epoch 15/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.6662 - loss: 1.1843
# Epoch 15: val_accuracy improved from 0.67493 to 0.70159, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 104s 345ms/step - accuracy: 0.6662 - loss: 1.1843 - val_accuracy: 0.7016 - val_loss: 1.1000 - learning_rate: 4.8767e-04
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.000463291230159753.
# Epoch 16/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.6852 - loss: 1.1527
# Epoch 16: val_accuracy improved from 0.70159 to 0.70533, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 104s 344ms/step - accuracy: 0.6852 - loss: 1.1528 - val_accuracy: 0.7053 - val_loss: 1.0831 - learning_rate: 4.6329e-04
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.00044012666865176535.
# Epoch 17/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.6886 - loss: 1.1479
# Epoch 17: val_accuracy did not improve from 0.70533
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 104s 346ms/step - accuracy: 0.6886 - loss: 1.1479 - val_accuracy: 0.6679 - val_loss: 1.2357 - learning_rate: 4.4013e-04
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.0004181203352191771.
# Epoch 18/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.7000 - loss: 1.1181
# Epoch 18: val_accuracy did not improve from 0.70533
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 104s 346ms/step - accuracy: 0.7000 - loss: 1.1182 - val_accuracy: 0.7016 - val_loss: 1.0844 - learning_rate: 4.1812e-04
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.0003972143184582182.
# Epoch 19/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.6966 - loss: 1.1169
# Epoch 19: val_accuracy improved from 0.70533 to 0.71703, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 104s 346ms/step - accuracy: 0.6966 - loss: 1.1169 - val_accuracy: 0.7170 - val_loss: 1.0420 - learning_rate: 3.9721e-04
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.00037735360253530727.
# Epoch 20/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.7061 - loss: 1.0970
# Epoch 20: val_accuracy did not improve from 0.71703
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 340ms/step - accuracy: 0.7061 - loss: 1.0970 - val_accuracy: 0.7081 - val_loss: 1.0683 - learning_rate: 3.7735e-04
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.0005.
# Epoch 21/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.6943 - loss: 1.1168
# Epoch 21: val_accuracy did not improve from 0.71703
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 340ms/step - accuracy: 0.6943 - loss: 1.1168 - val_accuracy: 0.7142 - val_loss: 1.0825 - learning_rate: 5.0000e-04
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.0003405616262881148.
# Epoch 22/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.7070 - loss: 1.1083
# Epoch 22: val_accuracy did not improve from 0.71703
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 341ms/step - accuracy: 0.7070 - loss: 1.1083 - val_accuracy: 0.7021 - val_loss: 1.1054 - learning_rate: 3.4056e-04
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.000323533544973709.
# Epoch 23/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.7168 - loss: 1.0702
# Epoch 23: val_accuracy improved from 0.71703 to 0.72498, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 106s 353ms/step - accuracy: 0.7168 - loss: 1.0702 - val_accuracy: 0.7250 - val_loss: 1.0404 - learning_rate: 3.2353e-04
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.00030735686772502356.
# Epoch 24/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.7245 - loss: 1.0471
# Epoch 24: val_accuracy did not improve from 0.72498
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 341ms/step - accuracy: 0.7245 - loss: 1.0471 - val_accuracy: 0.7240 - val_loss: 1.0165 - learning_rate: 3.0736e-04
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.0002919890243387724.
# Epoch 25/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.7227 - loss: 1.0291
# Epoch 25: val_accuracy improved from 0.72498 to 0.75585, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 104s 348ms/step - accuracy: 0.7227 - loss: 1.0291 - val_accuracy: 0.7558 - val_loss: 0.9516 - learning_rate: 2.9199e-04
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.00027738957312183375.
# Epoch 26/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7319 - loss: 1.0138
# Epoch 26: val_accuracy did not improve from 0.75585
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 101s 336ms/step - accuracy: 0.7319 - loss: 1.0138 - val_accuracy: 0.7549 - val_loss: 0.9296 - learning_rate: 2.7739e-04
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.00026352009446574203.
# Epoch 27/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.7342 - loss: 0.9983
# Epoch 27: val_accuracy did not improve from 0.75585
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 340ms/step - accuracy: 0.7342 - loss: 0.9983 - val_accuracy: 0.7442 - val_loss: 0.9670 - learning_rate: 2.6352e-04
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.00025034408974245495.
# Epoch 28/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.7390 - loss: 0.9772
# Epoch 28: val_accuracy did not improve from 0.75585
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 104s 347ms/step - accuracy: 0.7390 - loss: 0.9773 - val_accuracy: 0.7516 - val_loss: 0.9631 - learning_rate: 2.5034e-04
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.00023782688525533216.
# Epoch 29/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7402 - loss: 0.9678
# Epoch 29: val_accuracy did not improve from 0.75585
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 338ms/step - accuracy: 0.7402 - loss: 0.9678 - val_accuracy: 0.7376 - val_loss: 0.9546 - learning_rate: 2.3783e-04
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.00022593554099256555.
# Epoch 30/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.7369 - loss: 0.9726
# Epoch 30: val_accuracy did not improve from 0.75585
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 338ms/step - accuracy: 0.7369 - loss: 0.9725 - val_accuracy: 0.7278 - val_loss: 0.9789 - learning_rate: 2.2594e-04
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.00021463876394293727.
# Epoch 31/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.7485 - loss: 0.9449
# Epoch 31: val_accuracy did not improve from 0.75585
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 340ms/step - accuracy: 0.7486 - loss: 0.9448 - val_accuracy: 0.7554 - val_loss: 0.9122 - learning_rate: 2.1464e-04
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.00020390682574579038.
# Epoch 32/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.7475 - loss: 0.9260
# Epoch 32: val_accuracy did not improve from 0.75585
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 101s 336ms/step - accuracy: 0.7475 - loss: 0.9261 - val_accuracy: 0.7479 - val_loss: 0.9457 - learning_rate: 2.0391e-04
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.00019371148445850088.
# Epoch 33/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.7530 - loss: 0.9379
# Epoch 33: val_accuracy improved from 0.75585 to 0.75725, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 339ms/step - accuracy: 0.7530 - loss: 0.9378 - val_accuracy: 0.7572 - val_loss: 0.8986 - learning_rate: 1.9371e-04
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.00018402591023557584.
# Epoch 34/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7478 - loss: 0.9303
# Epoch 34: val_accuracy did not improve from 0.75725
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 101s 336ms/step - accuracy: 0.7479 - loss: 0.9303 - val_accuracy: 0.7240 - val_loss: 0.9885 - learning_rate: 1.8403e-04
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.000174824614723797.
# Epoch 35/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.7597 - loss: 0.8899
# Epoch 35: val_accuracy improved from 0.75725 to 0.76707, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 103s 342ms/step - accuracy: 0.7597 - loss: 0.8899 - val_accuracy: 0.7671 - val_loss: 0.8614 - learning_rate: 1.7482e-04
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.00016608338398760718.
# Epoch 36/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.7566 - loss: 0.8966
# Epoch 36: val_accuracy did not improve from 0.76707
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 340ms/step - accuracy: 0.7566 - loss: 0.8966 - val_accuracy: 0.7629 - val_loss: 0.8777 - learning_rate: 1.6608e-04
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.0001577792147882268.
# Epoch 37/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.7595 - loss: 0.8923
# Epoch 37: val_accuracy improved from 0.76707 to 0.77456, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 103s 342ms/step - accuracy: 0.7595 - loss: 0.8923 - val_accuracy: 0.7746 - val_loss: 0.8473 - learning_rate: 1.5778e-04
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.00014989025404881545.
# Epoch 38/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.7695 - loss: 0.8645
# Epoch 38: val_accuracy did not improve from 0.77456
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 100s 332ms/step - accuracy: 0.7695 - loss: 0.8645 - val_accuracy: 0.7703 - val_loss: 0.8579 - learning_rate: 1.4989e-04
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.00014239574134637466.
# Epoch 39/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.7717 - loss: 0.8474
# Epoch 39: val_accuracy did not improve from 0.77456
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 340ms/step - accuracy: 0.7717 - loss: 0.8475 - val_accuracy: 0.7666 - val_loss: 0.8512 - learning_rate: 1.4240e-04
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.00013527595427905592.
# Epoch 40/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.7748 - loss: 0.8580
# Epoch 40: val_accuracy did not improve from 0.77456
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 339ms/step - accuracy: 0.7747 - loss: 0.8580 - val_accuracy: 0.7703 - val_loss: 0.8514 - learning_rate: 1.3528e-04
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.0005.
# Epoch 41/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.7428 - loss: 0.9542
# Epoch 41: val_accuracy did not improve from 0.77456
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 100s 334ms/step - accuracy: 0.7428 - loss: 0.9543 - val_accuracy: 0.7250 - val_loss: 1.0295 - learning_rate: 5.0000e-04
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.00012208654873684796.
# Epoch 42/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.7492 - loss: 0.9534
# Epoch 42: val_accuracy did not improve from 0.77456
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 103s 342ms/step - accuracy: 0.7493 - loss: 0.9534 - val_accuracy: 0.7689 - val_loss: 0.8827 - learning_rate: 1.2209e-04
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.00011598222130000556.
# Epoch 43/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7633 - loss: 0.8940
# Epoch 43: val_accuracy did not improve from 0.77456
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 101s 337ms/step - accuracy: 0.7633 - loss: 0.8940 - val_accuracy: 0.7685 - val_loss: 0.8766 - learning_rate: 1.1598e-04
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.00011018311023500529.
# Epoch 44/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7639 - loss: 0.8929
# Epoch 44: val_accuracy improved from 0.77456 to 0.77643, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 341ms/step - accuracy: 0.7639 - loss: 0.8929 - val_accuracy: 0.7764 - val_loss: 0.8517 - learning_rate: 1.1018e-04
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.00010467395472325501.
# Epoch 45/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7767 - loss: 0.8646
# Epoch 45: val_accuracy did not improve from 0.77643
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 101s 336ms/step - accuracy: 0.7767 - loss: 0.8646 - val_accuracy: 0.7750 - val_loss: 0.8483 - learning_rate: 1.0467e-04
#
# Epoch 46: LearningRateScheduler setting learning rate to 9.944025698709225e-05.
# Epoch 46/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7778 - loss: 0.8508
# Epoch 46: val_accuracy did not improve from 0.77643
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 101s 337ms/step - accuracy: 0.7778 - loss: 0.8508 - val_accuracy: 0.7661 - val_loss: 0.8509 - learning_rate: 9.9440e-05
#
# Epoch 47: LearningRateScheduler setting learning rate to 9.446824413773763e-05.
# Epoch 47/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.7709 - loss: 0.8468
# Epoch 47: val_accuracy did not improve from 0.77643
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 101s 335ms/step - accuracy: 0.7709 - loss: 0.8467 - val_accuracy: 0.7741 - val_loss: 0.8379 - learning_rate: 9.4468e-05
#
# Epoch 48: LearningRateScheduler setting learning rate to 8.974483193085076e-05.
# Epoch 48/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.7829 - loss: 0.8259
# Epoch 48: val_accuracy improved from 0.77643 to 0.77877, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 338ms/step - accuracy: 0.7829 - loss: 0.8259 - val_accuracy: 0.7788 - val_loss: 0.8276 - learning_rate: 8.9745e-05
#
# Epoch 49: LearningRateScheduler setting learning rate to 8.52575903343082e-05.
# Epoch 49/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.7814 - loss: 0.8208
# Epoch 49: val_accuracy improved from 0.77877 to 0.78204, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 103s 343ms/step - accuracy: 0.7814 - loss: 0.8208 - val_accuracy: 0.7820 - val_loss: 0.8082 - learning_rate: 8.5258e-05
#
# Epoch 50: LearningRateScheduler setting learning rate to 8.099471081759279e-05.
# Epoch 50/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7838 - loss: 0.8182
# Epoch 50: val_accuracy did not improve from 0.78204
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 101s 338ms/step - accuracy: 0.7838 - loss: 0.8182 - val_accuracy: 0.7788 - val_loss: 0.8151 - learning_rate: 8.0995e-05
#
# Epoch 51: LearningRateScheduler setting learning rate to 7.694497527671315e-05.
# Epoch 51/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.7877 - loss: 0.8072
# Epoch 51: val_accuracy did not improve from 0.78204
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 339ms/step - accuracy: 0.7878 - loss: 0.8072 - val_accuracy: 0.7774 - val_loss: 0.8242 - learning_rate: 7.6945e-05
#
# Epoch 52: LearningRateScheduler setting learning rate to 7.30977265128775e-05.
# Epoch 52/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.7957 - loss: 0.7795
# Epoch 52: val_accuracy did not improve from 0.78204
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 340ms/step - accuracy: 0.7957 - loss: 0.7796 - val_accuracy: 0.7755 - val_loss: 0.8188 - learning_rate: 7.3098e-05
#
# Epoch 53: LearningRateScheduler setting learning rate to 6.94428401872336e-05.
# Epoch 53/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7892 - loss: 0.7927
# Epoch 53: val_accuracy did not improve from 0.78204
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 101s 337ms/step - accuracy: 0.7892 - loss: 0.7927 - val_accuracy: 0.7811 - val_loss: 0.8156 - learning_rate: 6.9443e-05
#
# Epoch 54: LearningRateScheduler setting learning rate to 6.597069817787194e-05.
# Epoch 54/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.7928 - loss: 0.7864
# Epoch 54: val_accuracy did not improve from 0.78204
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 338ms/step - accuracy: 0.7928 - loss: 0.7864 - val_accuracy: 0.7792 - val_loss: 0.8237 - learning_rate: 6.5971e-05
#
# Epoch 55: LearningRateScheduler setting learning rate to 6.267216326897833e-05.
# Epoch 55/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.7972 - loss: 0.7605
# Epoch 55: val_accuracy improved from 0.78204 to 0.78438, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 103s 343ms/step - accuracy: 0.7972 - loss: 0.7606 - val_accuracy: 0.7844 - val_loss: 0.7993 - learning_rate: 6.2672e-05
#
# Epoch 56: LearningRateScheduler setting learning rate to 5.953855510552941e-05.
# Epoch 56/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.7979 - loss: 0.7646
# Epoch 56: val_accuracy did not improve from 0.78438
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 104s 345ms/step - accuracy: 0.7979 - loss: 0.7646 - val_accuracy: 0.7825 - val_loss: 0.8032 - learning_rate: 5.9539e-05
#
# Epoch 57: LearningRateScheduler setting learning rate to 5.656162735025293e-05.
# Epoch 57/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.7986 - loss: 0.7633
# Epoch 57: val_accuracy improved from 0.78438 to 0.78812, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 106s 352ms/step - accuracy: 0.7986 - loss: 0.7634 - val_accuracy: 0.7881 - val_loss: 0.8099 - learning_rate: 5.6562e-05
#
# Epoch 58: LearningRateScheduler setting learning rate to 5.373354598274029e-05.
# Epoch 58/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.8013 - loss: 0.7626
# Epoch 58: val_accuracy did not improve from 0.78812
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 107s 354ms/step - accuracy: 0.8013 - loss: 0.7626 - val_accuracy: 0.7844 - val_loss: 0.7957 - learning_rate: 5.3734e-05
#
# Epoch 59: LearningRateScheduler setting learning rate to 5.1046868683603266e-05.
# Epoch 59/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.7982 - loss: 0.7556
# Epoch 59: val_accuracy did not improve from 0.78812
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 105s 350ms/step - accuracy: 0.7982 - loss: 0.7557 - val_accuracy: 0.7862 - val_loss: 0.7926 - learning_rate: 5.1047e-05
#
# Epoch 60: LearningRateScheduler setting learning rate to 4.8494525249423105e-05.
# Epoch 60/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.8046 - loss: 0.7405
# Epoch 60: val_accuracy improved from 0.78812 to 0.78999, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 104s 347ms/step - accuracy: 0.8046 - loss: 0.7405 - val_accuracy: 0.7900 - val_loss: 0.7840 - learning_rate: 4.8495e-05
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.0005.
# Epoch 61/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.7527 - loss: 0.9017
# Epoch 61: val_accuracy did not improve from 0.78999
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 103s 343ms/step - accuracy: 0.7527 - loss: 0.9019 - val_accuracy: 0.7058 - val_loss: 1.0550 - learning_rate: 5.0000e-04
#
# Epoch 62: LearningRateScheduler setting learning rate to 4.3766309037604346e-05.
# Epoch 62/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.7497 - loss: 0.9406
# Epoch 62: val_accuracy did not improve from 0.78999
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 103s 342ms/step - accuracy: 0.7498 - loss: 0.9405 - val_accuracy: 0.7671 - val_loss: 0.8611 - learning_rate: 4.3766e-05
#
# Epoch 63: LearningRateScheduler setting learning rate to 4.157799358572413e-05.
# Epoch 63/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.7674 - loss: 0.8825
# Epoch 63: val_accuracy did not improve from 0.78999
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 338ms/step - accuracy: 0.7675 - loss: 0.8824 - val_accuracy: 0.7760 - val_loss: 0.8381 - learning_rate: 4.1578e-05
#
# Epoch 64: LearningRateScheduler setting learning rate to 3.949909390643792e-05.
# Epoch 64/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.7774 - loss: 0.8571
# Epoch 64: val_accuracy did not improve from 0.78999
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 339ms/step - accuracy: 0.7774 - loss: 0.8571 - val_accuracy: 0.7844 - val_loss: 0.8281 - learning_rate: 3.9499e-05
#
# Epoch 65: LearningRateScheduler setting learning rate to 3.752413921111602e-05.
# Epoch 65/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.7771 - loss: 0.8437
# Epoch 65: val_accuracy did not improve from 0.78999
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 101s 335ms/step - accuracy: 0.7771 - loss: 0.8437 - val_accuracy: 0.7774 - val_loss: 0.8275 - learning_rate: 3.7524e-05
#
# Epoch 66: LearningRateScheduler setting learning rate to 3.564793225056022e-05.
# Epoch 66/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.7867 - loss: 0.8259
# Epoch 66: val_accuracy did not improve from 0.78999
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 339ms/step - accuracy: 0.7867 - loss: 0.8259 - val_accuracy: 0.7853 - val_loss: 0.8133 - learning_rate: 3.5648e-05
#
# Epoch 67: LearningRateScheduler setting learning rate to 3.386553563803221e-05.
# Epoch 67/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.7924 - loss: 0.8050
# Epoch 67: val_accuracy improved from 0.78999 to 0.79280, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 104s 345ms/step - accuracy: 0.7924 - loss: 0.8050 - val_accuracy: 0.7928 - val_loss: 0.8126 - learning_rate: 3.3866e-05
#
# Epoch 68: LearningRateScheduler setting learning rate to 3.217225885613059e-05.
# Epoch 68/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.7900 - loss: 0.8031
# Epoch 68: val_accuracy improved from 0.79280 to 0.79373, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 340ms/step - accuracy: 0.7900 - loss: 0.8031 - val_accuracy: 0.7937 - val_loss: 0.8081 - learning_rate: 3.2172e-05
#
# Epoch 69: LearningRateScheduler setting learning rate to 3.0563645913324066e-05.
# Epoch 69/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7889 - loss: 0.7956
# Epoch 69: val_accuracy did not improve from 0.79373
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 101s 337ms/step - accuracy: 0.7889 - loss: 0.7956 - val_accuracy: 0.7928 - val_loss: 0.8022 - learning_rate: 3.0564e-05
#
# Epoch 70: LearningRateScheduler setting learning rate to 2.903546361765786e-05.
# Epoch 70/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7978 - loss: 0.7862
# Epoch 70: val_accuracy did not improve from 0.79373
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 101s 337ms/step - accuracy: 0.7978 - loss: 0.7862 - val_accuracy: 0.7886 - val_loss: 0.8010 - learning_rate: 2.9035e-05
#
# Epoch 71: LearningRateScheduler setting learning rate to 2.7583690436774966e-05.
# Epoch 71/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.8006 - loss: 0.7739
# Epoch 71: val_accuracy did not improve from 0.79373
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 338ms/step - accuracy: 0.8006 - loss: 0.7739 - val_accuracy: 0.7881 - val_loss: 0.8003 - learning_rate: 2.7584e-05
#
# Epoch 72: LearningRateScheduler setting learning rate to 2.6204505914936218e-05.
# Epoch 72/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.7938 - loss: 0.7778
# Epoch 72: val_accuracy did not improve from 0.79373
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 103s 343ms/step - accuracy: 0.7938 - loss: 0.7778 - val_accuracy: 0.7848 - val_loss: 0.7982 - learning_rate: 2.6205e-05
#
# Epoch 73: LearningRateScheduler setting learning rate to 2.4894280619189404e-05.
# Epoch 73/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.7978 - loss: 0.7720
# Epoch 73: val_accuracy did not improve from 0.79373
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 103s 342ms/step - accuracy: 0.7978 - loss: 0.7720 - val_accuracy: 0.7886 - val_loss: 0.7959 - learning_rate: 2.4894e-05
#
# Epoch 74: LearningRateScheduler setting learning rate to 2.3649566588229933e-05.
# Epoch 74/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8009 - loss: 0.7761
# Epoch 74: val_accuracy did not improve from 0.79373
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 101s 336ms/step - accuracy: 0.8009 - loss: 0.7761 - val_accuracy: 0.7881 - val_loss: 0.7932 - learning_rate: 2.3650e-05
#
# Epoch 75: LearningRateScheduler setting learning rate to 2.2467088258818436e-05.
# Epoch 75/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7954 - loss: 0.7751
# Epoch 75: val_accuracy did not improve from 0.79373
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 338ms/step - accuracy: 0.7954 - loss: 0.7751 - val_accuracy: 0.7881 - val_loss: 0.7926 - learning_rate: 2.2467e-05
#
# Epoch 76: LearningRateScheduler setting learning rate to 2.134373384587751e-05.
# Epoch 76/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.7986 - loss: 0.7717
# Epoch 76: val_accuracy improved from 0.79373 to 0.79467, saving model to model.keras
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 103s 343ms/step - accuracy: 0.7986 - loss: 0.7717 - val_accuracy: 0.7947 - val_loss: 0.7932 - learning_rate: 2.1344e-05
#
# Epoch 77: LearningRateScheduler setting learning rate to 2.0276547153583635e-05.
# Epoch 77/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.7985 - loss: 0.7663
# Epoch 77: val_accuracy did not improve from 0.79467
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 101s 334ms/step - accuracy: 0.7985 - loss: 0.7663 - val_accuracy: 0.7881 - val_loss: 0.7894 - learning_rate: 2.0277e-05
#
# Epoch 78: LearningRateScheduler setting learning rate to 1.9262719795904453e-05.
# Epoch 78/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.7978 - loss: 0.7613
# Epoch 78: val_accuracy did not improve from 0.79467
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 339ms/step - accuracy: 0.7978 - loss: 0.7613 - val_accuracy: 0.7848 - val_loss: 0.7898 - learning_rate: 1.9263e-05
#
# Epoch 79: LearningRateScheduler setting learning rate to 1.8299583806109228e-05.
# Epoch 79/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8068 - loss: 0.7497
# Epoch 79: val_accuracy did not improve from 0.79467
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 101s 337ms/step - accuracy: 0.8068 - loss: 0.7497 - val_accuracy: 0.7909 - val_loss: 0.7863 - learning_rate: 1.8300e-05
#
# Epoch 80: LearningRateScheduler setting learning rate to 1.7384604615803768e-05.
# Epoch 80/80
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.8020 - loss: 0.7536
# Epoch 80: val_accuracy did not improve from 0.79467
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 102s 339ms/step - accuracy: 0.8020 - loss: 0.7536 - val_accuracy: 0.7900 - val_loss: 0.7826 - learning_rate: 1.7385e-05
# Restoring model weights from the end of the best epoch: 76.
# Best validation model: epoch 76  - val_accuracy 0.7946678996086121

# %%
#PLOTS

import matplotlib.pyplot as plt

# Create subplots with custom styling
plt.figure(figsize=(12, 5), dpi=300)
plt.style.use('seaborn-whitegrid')

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(h.history['loss'], color='#1f77b4', linewidth=2, label='Train')
plt.plot(h.history['val_loss'], color='#ff7f0e', linewidth=2, linestyle='--', label='Validation')
plt.title('Training Evolution: Loss', fontsize=12, pad=20)
plt.ylabel('Categorical Crossentropy', fontsize=10)
plt.xlabel('Epoch', fontsize=10)
plt.legend(frameon=True, facecolor='white')

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(h.history['accuracy'], color='#1f77b4', linewidth=2, label='Train')
plt.plot(h.history['val_accuracy'], color='#ff7f0e', linewidth=2, linestyle='--', label='Validation')
plt.title('Training Evolution: Accuracy', fontsize=12, pad=20)
plt.ylabel('Accuracy (%)', fontsize=10)
plt.xlabel('Epoch', fontsize=10)
plt.legend(frameon=True, facecolor='white')

plt.tight_layout()
plt.savefig('training_evolution.png', bbox_inches='tight', transparent=False)
plt.show()
# Out:
# <ipython-input-15-b3401fe3e391>:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.get_cmap('Blues'))
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show(fig)

# %%
import numpy as np

model.load_weights('model.keras') #, by_name=True
y_true, y_pred = [], []
for ann in anns_valid:
    # Load image
    image = load_geoimage(ann.filename)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        y_true.append(obj_pred.category)
        y_pred.append(pred_category)

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)
# Out:
# <ipython-input-16-39df9ea0fe34>:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.get_cmap('Blues'))

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 79.467%
# Mean Recall: 76.414%
# Mean Precision: 75.654%
# > Cargo plane: Recall: 88.235% Precision: 98.361% Specificity: 99.952% Dice: 93.023%
# > Helicopter: Recall: 50.000% Precision: 25.000% Specificity: 99.860% Dice: 33.333%
# > Small car: Recall: 91.667% Precision: 80.882% Specificity: 94.703% Dice: 85.938%
# > Bus: Recall: 63.927% Precision: 68.293% Specificity: 96.613% Dice: 66.038%
# > Truck: Recall: 48.679% Precision: 54.661% Specificity: 94.287% Dice: 51.497%
# > Motorboat: Recall: 84.270% Precision: 73.529% Specificity: 98.682% Dice: 78.534%
# > Fishing vessel: Recall: 85.714% Precision: 89.189% Specificity: 99.612% Dice: 87.417%
# > Dump truck: Recall: 61.538% Precision: 69.903% Specificity: 98.466% Dice: 65.455%
# > Excavator: Recall: 88.462% Precision: 90.789% Specificity: 99.660% Dice: 89.610%
# > Building: Recall: 90.927% Precision: 90.744% Specificity: 97.199% Dice: 90.836%
# > Storage tank: Recall: 86.928% Precision: 93.662% Specificity: 99.547% Dice: 90.169%
# > Shipping container: Recall: 76.623% Precision: 72.840% Specificity: 97.782% Dice: 74.684%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
for (dirpath, dirnames, filenames) in os.walk('/kaggle/input/files/xview_recognition/xview_test'):
    for filename in filenames:
        image = GenericImage(dirpath[18:]+'/'+filename)
        image.tile = np.array([0, 0, 224, 224])
        obj = GenericObject()
        obj.bb = (0, 0, 224, 224)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2635

# %%
import numpy as np

model.load_weights('model.keras') #, by_name=True
predictions_data = {"images": {}, "annotations": {}}
for idx, ann in enumerate(anns):
    file_name = ann.filename.split('/')[-1]
    image_data = {"image_id": file_name, "filename": file_name, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
    predictions_data["images"][idx] = image_data
    # Load image
    image = load_geoimage('xview_test/' + file_name)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
        predictions_data["annotations"][idx] = annotation_data

# %%
with open("/kaggle/working/prediction_third.json", "w") as outfile:
    json.dump(predictions_data, outfile)
